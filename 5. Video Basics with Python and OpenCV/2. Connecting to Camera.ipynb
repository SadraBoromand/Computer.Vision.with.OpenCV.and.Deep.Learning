# %%
import cv2

# %%
cap = cv2.VideoCapture(0)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # 1080.0 shoude be int
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# WINDOWS -- *'DIVX'
# MACOS or LINUX -- *'XVID'

writer = cv2.VideoWriter('mysupervide.mp4',cv2.VideoWriter_fourcc(*'DIVX'),20,(width,height))

while True:
    ret,frame = cap.read()
    
#     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

#     OPERATIONS (DRAWING)
    writer.write(frame)

    cv2.imshow('frame',frame)
    
#     if cv2.waitKey(1) & 0xFF == 27 &:
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
        
cap.release()
writer.release()
cv2.destroyAllWindows()

# %%
# Out:
# 0.0

# %%
pwd
# Out:
# 'C:\\Users\\SADRA\\Desktop\\py\\5. Video Basics with Python and OpenCV'
